# %%
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="Add Your Key",client_secret="Add Your Key")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/1eQ2qqs4cTHcHGsCYZMMEy"

# %%
playlist_URI = playlist_link.split("/")[4]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
len(data['items'])
# Out:
# 32

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Mangalashtak Once More (Original Motion Picture Soundtrack)'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id' : album_id,
                    'album_name' : album_name,
                    'album_release_date' : album_release_date,
                    'album_total_tracks' : album_total_tracks,
                    'album_url' : album_url}
    album_list.append(album_element)

# %%
album_list[3]
# Out:
# {'album_id': '3Drcm4n1w7gPFPsx48ETBQ',
#  'album_name': 'Tula Pahile',
#  'album_release_date': '2011',
#  'album_total_tracks': 9,
#  'album_url': 'https://open.spotify.com/album/3Drcm4n1w7gPFPsx48ETBQ'}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   6TVpwz5vAHBWsLGoTmRB3Q  Mangalashtak Once More (Original Motion Pictur...
# 1   75ymwdW6EBrxSuCiuFxWC3                                 Mumbai Pune Mumbai
# 2   59jmUikonSbsZwcTm7zBHK  One Way Ticket (Original Motion Picture Soundt...
# 3   3Drcm4n1w7gPFPsx48ETBQ                                        Tula Pahile
# 4   4gay2e6Pt8tEE9EkGrtJAT      Tu Hi Re (Original Motion Picture Soundtrack)
# 5   3RWXrQIcsfbOBjr6ZwqO0U                                Yanda Kartavya Aahe
# 6   47lmJGpSMo41T33AR1p5RC                               Mumbai Pune Mumbai 3
# 7   1oSf0fci7TvgDZYzBSMj25   Irada Pakka (Original Motion Picture Soundtrack)
# 8   5KnimA7qlA5fXyv4461t9g                               Mumbai Pune Mumbai 2
# 9   2FeTXpBk0e2YGAyne1BU2u        Mitwaa (Original Motion Picture Soundtrack)
# 10  2K02TquSnJBGihbB3m8xTK                     Saavar Re Mana (From "Mitwaa")
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            32 non-null     object
#  1   album_name          32 non-null     object
#  2   album_release_date  32 non-null     object
#  3   album_total_tracks  32 non-null     int64
#  4   album_url           32 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.4+ KB

# %%
album_df = album_df.drop_duplicates(subset='album_id')

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   6TVpwz5vAHBWsLGoTmRB3Q  Mangalashtak Once More (Original Motion Pictur...
# 1   75ymwdW6EBrxSuCiuFxWC3                                 Mumbai Pune Mumbai
# 2   59jmUikonSbsZwcTm7zBHK  One Way Ticket (Original Motion Picture Soundt...
# 3   3Drcm4n1w7gPFPsx48ETBQ                                        Tula Pahile
# 4   4gay2e6Pt8tEE9EkGrtJAT      Tu Hi Re (Original Motion Picture Soundtrack)
# 5   3RWXrQIcsfbOBjr6ZwqO0U                                Yanda Kartavya Aahe
# 6   47lmJGpSMo41T33AR1p5RC                               Mumbai Pune Mumbai 3
# 7   1oSf0fci7TvgDZYzBSMj25   Irada Pakka (Original Motion Picture Soundtrack)
# 8   5KnimA7qlA5fXyv4461t9g                               Mumbai Pune Mumbai 2
# 9   2FeTXpBk0e2YGAyne1BU2u        Mitwaa (Original Motion Picture Soundtrack)
# 10  2K02TquSnJBGihbB3m8xTK                     Saavar Re Mana (From "Mitwaa")
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id             artist_name  \
# 0   4Wil7eB65FIL818mwO5dIc         Abhijeet Sawant
# 1   60f431EIEmwOfJJOJhdyQR             Bela Shende
# 2   5FYfbwgI1HqPzzRiBm62Ve       Hrishikesh Ranade
# 3   5jW93KBgv7vhPpBqbcLxWy        Gaurav Dagaonkar
# 4   7qj8b5tuzeSkb4ff01h5rJ           Aanandi Joshi
# 5   5yHnIri2Bj5Ysuaki6VOVy       Swapnil Bandodkar
# 6   46ui8RBe32jfIZiQ02NqTX                 Amitraj
# 7   60f431EIEmwOfJJOJhdyQR             Bela Shende
# 8   1NKmpPhLjRNBoFoc6TVH25             Guru Thakur
# 9   6XypcJDBmfuRjq52PFUVwd            Rahul Vaidya
# 10  2zGP2SUtwsDhdyYzf0kKp8         Vaishali Samant
# 11  5FYfbwgI1HqPzzRiBm62Ve       Hrishikesh Ranade
# 12  1W8O3VMkoLKHlnPtojVU8l           Kshitij Tarey
# 13  4cSJs8KQW0qPqIEOyXsWix  Nihira Joshi Deshpande
# 14  60f431EIEmwOfJJOJhdyQR             Bela Shende
# 15  5FYfbwgI1HqPzzRiBm62Ve       Hrishikesh Ranade
# 16  1SJOL9HJ08YOn92lFcYf8a       Shankar Mahadevan
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                 song_name  \
# 0   2nfr9OCxsUju4sg10oRCxe                     Sar Sukhachi Shravani
# 1   1as3se3lgcMyc3fv5ZqSiP                                  Kadhi Tu
# 2   6Atl05mb8CcUVQPwjowAAo                           Reshami Reshami
# 3   18ypSJqg0pN5p9KMuaGFLf                               Radha Radha
# 4   7FjnFOfObgTCHsfrSVEfQO                                 Tola Tola
# 5   4miR4hZGvWN98NT8bvDRut                                 Aabhas Ha
# 6   7srKnb4zE4J3zMKYuiXBj7                               Tula Pahata
# 7   5TatEBJpqXuSQYkESGOWVc                          Bhijun Gela Vara
# 8   7vDtZ3SEjsxb4h0ILwHgq4                           Sath De Tu Mala
# 9   5N7G544kaBi3rWWTPjsdu7                                    Mitwaa
# 10  70OzwqFfeL0Mb3A9MUmA4R            Saavar Re Mana - From "Mitwaa"
# 11  3pCg29CErkhjvJfEpuJoZx  Chimbh Bhijalele - From "Bandh Premache"
# 12  2XthhAhyRpnDpc4ml9299K                      Kiti Sangaichay Mala
# ...

# %%
album_df.head()
# Out:
#                  album_id                                         album_name  \
# 0  6TVpwz5vAHBWsLGoTmRB3Q  Mangalashtak Once More (Original Motion Pictur...
# 1  75ymwdW6EBrxSuCiuFxWC3                                 Mumbai Pune Mumbai
# 2  59jmUikonSbsZwcTm7zBHK  One Way Ticket (Original Motion Picture Soundt...
# 3  3Drcm4n1w7gPFPsx48ETBQ                                        Tula Pahile
# 4  4gay2e6Pt8tEE9EkGrtJAT      Tu Hi Re (Original Motion Picture Soundtrack)
#
#   album_release_date  album_total_tracks  \
# 0         2013-01-01                   4
# 1         2010-06-11                   6
# 2         2016-09-09                   5
# 3               2011                   9
# 4         2015-01-01                   5
#
#                                            album_url
# 0  https://open.spotify.com/album/6TVpwz5vAHBWsLG...
# 1  https://open.spotify.com/album/75ymwdW6EBrxSuC...
# 2  https://open.spotify.com/album/59jmUikonSbsZwc...
# ...

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  4Wil7eB65FIL818mwO5dIc    Abhijeet Sawant
# 1  60f431EIEmwOfJJOJhdyQR        Bela Shende
# 2  5FYfbwgI1HqPzzRiBm62Ve  Hrishikesh Ranade
# 3  5jW93KBgv7vhPpBqbcLxWy   Gaurav Dagaonkar
# 4  7qj8b5tuzeSkb4ff01h5rJ      Aanandi Joshi
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4Wil7eB65FI...
# 1  https://api.spotify.com/v1/artists/60f431EIEmw...
# 2  https://api.spotify.com/v1/artists/5FYfbwgI1Hq...
# 3  https://api.spotify.com/v1/artists/5jW93KBgv7v...
# 4  https://api.spotify.com/v1/artists/7qj8b5tuzeS...

# %%
song_df.head()
# Out:
#                   song_id              song_name  duration_ms  \
# 0  2nfr9OCxsUju4sg10oRCxe  Sar Sukhachi Shravani       397080
# 1  1as3se3lgcMyc3fv5ZqSiP               Kadhi Tu       338394
# 2  6Atl05mb8CcUVQPwjowAAo        Reshami Reshami       263575
# 3  18ypSJqg0pN5p9KMuaGFLf            Radha Radha       274853
# 4  7FjnFOfObgTCHsfrSVEfQO              Tola Tola       207960
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2nfr9OCxsUju4sg...          56
# 1  https://open.spotify.com/track/1as3se3lgcMyc3f...           0
# 2  https://open.spotify.com/track/6Atl05mb8CcUVQP...          42
# 3  https://open.spotify.com/track/18ypSJqg0pN5p9K...           0
# 4  https://open.spotify.com/track/7FjnFOfObgTCHsf...          57
#
#              song_added                album_id               artist_id
# 0  2023-04-25T14:48:09Z  6TVpwz5vAHBWsLGoTmRB3Q  2iefUd3zjUfJ7qeLDwT62g
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      32 non-null     object
#  1   song_name    32 non-null     object
#  2   duration_ms  32 non-null     int64
#  3   url          32 non-null     object
#  4   popularity   32 non-null     int64
#  5   song_added   32 non-null     object
#  6   album_id     32 non-null     object
#  7   artist_id    32 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 2.1+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      32 non-null     object
#  1   song_name    32 non-null     object
#  2   duration_ms  32 non-null     int64
#  3   url          32 non-null     object
#  4   popularity   32 non-null     int64
#  5   song_added   32 non-null     datetime64[ns, UTC]
#  6   album_id     32 non-null     object
#  7   artist_id    32 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 2.1+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            28 non-null     object
#  1   album_name          28 non-null     object
#  2   album_release_date  28 non-null     object
#  3   album_total_tracks  28 non-null     int64
#  4   album_url           28 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB

# %%
album_df.loc[:, 'album_release_date'] = pd.to_datetime(album_df['album_release_date'], format='mixed')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            28 non-null     object
#  1   album_name          28 non-null     object
#  2   album_release_date  28 non-null     object
#  3   album_total_tracks  28 non-null     int64
#  4   album_url           28 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB
